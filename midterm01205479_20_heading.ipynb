# %% [markdown]
# <a href="https://colab.research.google.com/github/dewdotninja/exams/blob/master/midterm01205479_20_heading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="left">
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/feng_heading_en.png" width=400 alt="Feng heading"/>
# </p>
#
# #### Midterm Exam, Second Semester, Academic Year 2020
# <br>01205479 Internet of Things for Electrial Engineering
# <br>Wednesday March 3, 2021 13.00 - 16.00
# <br>This exam is administered online via Google classroom only.
#
# Type student name - surname and ID in the cell below.

# %% [markdown]
# Kunanon Jarat 6010554802

# %% [markdown]
# ### Instructions
#
# 1. You can use Colab environment or install Jupyter notebook on your local machine.
# Type your work solely on this notebook. You can add as many cells as you want.
# Formatting is not necessary as long as your texts/equations are understandable and
# answer the question clearly.
# 2. Open books, notes and online resources.
# 3. Explain clearly. Show details of your computation to receive full credits. For any problem
# that requires programming, your program should executer without error and give the correct
# result.
# 4. Do not change any problem.
# 5. Some parameters in the problem set may be a function of your student ID. You must make sure
# to substitute the right value for such parameters.
# 6. In case you are totally hopeless with Python, the only other softwares that are allowed are MATLAB
# and Scilab. Students must provide complete MATLAB/Scilab scripts and also capture the
# output/graph images to the notebook by using the image tag with image files in a public URL.
# If some relevant information is missing, you may receive only partial credit. Since this is a
# time-consuming process and may be problematic, doing all your work with Python in Jupyter notebook
# is strongly recommended.
# 7. <b>Important : </b>Students must submit your notebook promptly, in Google classroom only,
# when the 3-hour exam period expires. Resubmission is acceptable only within the exam period.
# Anyone who submits/resubmits later than 10 minutes after the exam period, as indicated in the
# recorded history of Google classroom, may be considered cheating and may fail this exam.

# %% [markdown]
# <div align="left">
# <b>Assoc. Prof. Peerayuth Charnsethikul</b>  &emsp;      Head of Examination Committee
# <br><b>Asst. Prof. Prapot Kunthong</b>  &emsp;     Examination Committee
# <br><b>Dr. Varodom Toochinda</b>    &emsp;    Examination Committee
# </div>

# %% [markdown]
# #### Further explantion about exam problem that may depend on the last 3 digits of your student ID
#
# -------xyz (other digits are disregarded)
#
# In case any digit in the last 3 are 0, it must be replaced by 5.
#
# #### Examples
#
# Student A's ID - 6010555853 results in x = 8, y = 5, z = 3
#
# Student B 's ID - 6010546104 results in x = 1, y = 5, z = 4
#
# Student C 's ID - 6310055032 results in x = 5, y = 3, z = 2
#
# These valuess are used for all the problems in the exam where x,y,and/or z appear. In this
# sense, the results from each student should be different even computed using the same methods.
#
# Operations that may be applied to the variables.
#
# $+$ addition
#
#  $-$  subtraction
#
#  $*$  multiplication
#
#  $/$ division
#
# $**$ raise to the power (For example, x**z means $x^z$)
#
# including math opertions such as $\exp(x)$, $\sin(z*t)$
#
# If a variable is embedded in some digit of a value without any operation symbol,
# just replace that digit.
# <br>For example,  z=8 y = 3 $\Rightarrow$ 12z7 = 1287, 4.3y5 = 4.335
#
# Conditional statement may be used, such as
# if x<5 do task A, otherwise do task B
#
# <em>Example: </em> Let $R1 = 1000*x \,\Omega, C1 = 10*y \,\mu F$
#
# <ul>
# <li />Student A (x=8, y=5) does this problem with R1 = 8000 $\Omega$, C1 = 50 $\mu$F
# <li />Student B (x=1, y=5) does this problem with R1 = 1000 $\Omega$, C1 = 50 $\mu$F
# <li />Student C (x=5, y=3) does this problem with R1 = 5000 $\Omega$, C1 = 30 $\mu$F
# </ul>
#
# If any exam problem is not clear enough, write in a cell how you interpret it. If several
# students get confused on that problem, the grader may decide to give full credit to all.

# %% [markdown]
# #### Remarks
#
# In the examples that follow, assume the student ID is 6010555208 $\Rightarrow$ x = 2, y=5, z=8

# %%
# You need to install these libraries in the Colab environment
# !pip install slycot
# !pip install control

# %%
# import libraries you want to use
import numpy as np
import matplotlib.pyplot as plt
import control as ctl

# %% [markdown]
# ***
# #### Exam problem examples
#
# P1. From figure 1 let $V_S = z$ volts $R_S = 1000*x \,\Omega$, $R_L = 500*y \,\Omega$, compute $V_L$
#
# <p align="center">
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/example_prob.png" width=300 alt="Figure 1"/>
# </p>
# <div align="center"><b>Figure 1 voltage divider circuit</b></div>
#
# #### Solution

# %% [markdown]
# MY X Y Z :
#
# X = 8
#
# Y = 0
#
# Z = 2

# %%
X = 8
Y = 0
Z = 2

# %%
Vs = Z
Rs = 1000*X
Rl = 500*Y
Vl = (Rs/(Rs+Rl))*Vs
Vl
# Out:
# 2.0

# %% [markdown]
# #### Example of an answer that scores zero.

# %%
# I cannot do this. Please have some mercy. My GPA is under 2.00 now.

# %% [markdown]
# #### Example of an answer that may receive half credit or less.
#
# No derivation/explanation on where this result comes from.

# %%
Vl = 3.5

# %% [markdown]
# #### Example of an answer that receives full credit.

# %%
Vs = 8
Rs = 2000
Rl = 2500
Vl = (Rs/(Rs+Rl))*Vs
Vl
# Out:
# 3.5555555555555554

# %% [markdown]
# ***
# P2. Describe how you may use the circuit in figure 1 in an embedded or IoT application
#
# #### Solution

# %%
The circuit can be used to reduce an input voltage to acceptable level. Suppose an MCU on the left side ouputs a 5-V logic, but 
the input of MCU on the right side can tolerate no more than 3.3 volts. We can design R1, R2 such that the voltage level is 
reduced from 5 to 3.3 volts.

# %% [markdown]
# <b>Remark : </b>You can use either code or text cell to answer in words. No formatting is required. If a code cell is used, you
#     don't click run because it would cause error message.

# %% [markdown]
# ***
# P3. From figure 1, let $V_S(t) = z \cos(y*t)$ volt, $R_S = 1000*x \,\Omega$, $R_L = 500*y \,\Omega$, write a code to plot
# $V_L(t)$ compared to $V_S(t)$ in the same graph, for t = 0 - 1 sec
#
# #### Solution

# %%
# The values of Rs, RL are defined in the cell above, so you don't have to redefine them 

tvec = np.arange(0,1,0.01)
Vs = Z*np.cos(Y*tvec)
Vl = (Rs/(Rs+Rl))*Vs
plt.figure()
plt.plot(tvec,Vs,'b-',tvec,Vl,'r-')
plt.xlabel('time (s)')
plt.ylabel('volts')
plt.grid(True)
plt.legend(["Vs(t)","Vl(t)"])

# %%
# The values of Rs, RL are defined in the cell above, so you don't have to redefine them 

tvec = np.arange(0,1,0.01)
Vs = 8*np.cos(10*tvec)
Vl = (Rs/(Rs+Rl))*Vs
plt.figure()
plt.plot(tvec,Vs,'b-',tvec,Vl,'r-')
plt.xlabel('time (s)')
plt.ylabel('volts')
plt.grid(True)
plt.legend(["Vs(t)","Vl(t)"])

# %% [markdown]
# <b>Remark : </b> You must execute the cell that contains code to yield the plot.

# %% [markdown]
# ***
# X4. Plot the Bode frequency response LPF $H(s) = \frac{1}{0.01(x)s+1}$ to verify its cutoff frequency.
#
# #### Solution

# %%
num = 1
den = [0.01*X,1]  # x = 8
H = ctl.tf(num,den)
mag, ph, om = ctl.bode_plot(H, dB = True)

# %% [markdown]
# Example of correct answyer (use control library)

# %%
# use Python control library (already imported in above cell as ctl)
num = 1
den = [0.02,1]  # x = 2
H = ctl.tf(num,den)
mag, ph, om = ctl.bode_plot(H, dB = True)

# %% [markdown]
# Example of correct answer (use scipy.signal library. Obviously, Python control library requires less work)

# %%
# use Scipy.signal and matplotlib
from scipy import signal
num = 1
den = [0.02,1]  # x = 2
H = signal.TransferFunction(num,den)
w, mag, phase = signal.bode(H)
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.grid(True)
plt.xlabel("Frequency (rad/s)")
plt.ylabel("Gain (dB)")
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.grid(True)
plt.xlabel("Frequency (rad/s)")
plt.ylabel("Phase (deg)")
plt.show()

# %% [markdown]
# An example of acceptable answer using other software, though not recommended becuase it's time consuming
# (Only MATLAB or Scilab is allowed)

# %%
# copy the *complete* MATLAB or  Scilab script to a cell. Do not execute.
num = 1;
den = [0.02,1];
H = tf(num,den)
bode(H)

# %%
# Capture MATLAB plot to an impage file and upload to some public website, then copy URL to image tag to use in a text cell.
# For example,

<img src="https://raw.githubusercontent.com/dewdotninja/exams/main/MATLAB_bode.png" />

# The figure is shown as in the text cell below.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/MATLAB_bode.png" />

# %% [markdown]
# <div align=right>Update : Feb 20,2021 - 14:00</div>
